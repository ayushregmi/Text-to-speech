# %%
import yaml
import os
from tqdm import tqdm
from text import _clean_text
from scipy.io import wavfile
import librosa
import numpy as np
from scipy.interpolate import interp1d
import tgt
import pyworld as pw
from sklearn.preprocessing import StandardScaler
from audio import *
import random
import json

# %%
class Preprocessor:
    
    
    def __init__(self, preprocessor_config_path):
        self.config = yaml.load(open(preprocessor_config_path, "r"), Loader=yaml.FullLoader)
        self.in_dir = self.config["path"]["raw_path"]
        self.out_dir = self.config["path"]["preprocessed_path"]
        self.val_size = self.config["preprocessing"]["val_size"]
        self.sampling_rate = self.config["preprocessing"]["audio"]["sampling_rate"]
        self.hop_length = self.config["preprocessing"]["stft"]["hop_length"]
        self.pitch_averaging = "phoneme_level"
        self.energy_averaging= "phoneme level"
        
        self.stft = audio.stft.TacotronSTFT(
            filter_length = self.config["preprocessing"]["stft"]["filter_length"],
            hop_length = self.config["preprocessing"]["stft"]["hop_length"],
            win_length = self.config["preprocessing"]["stft"]["win_length"],
            n_mel_channels = self.config["preprocessing"]["mel"]["n_mel_channels"],
            sampling_rate = self.config["preprocessing"]["audio"]["sampling_rate"],
            mel_fmin = self.config["preprocessing"]["mel"]["mel_fmin"],
            mel_fmax = self.config["preprocessing"]["mel"]["mel_fmax"]
        )
    
    
    #read the original LJspeech dataset. Cleans the text and normalizes the wave files.
    def preprocess_normalize(self):
        
        
        in_dir = self.config['path']['corpus_path']
        out_dir = self.config['path']['raw_path']
        
        max_wav_val = self.config['preprocessing']['audio']['max_wav_value']
        sampling_rate = self.config['preprocessing']['audio']['sampling_rate']
        
        with open(in_dir+"/metadata.csv") as file:
            for line in tqdm(file, ncols=100):
                columns = line.strip().split('|')
                text = columns[2]
                file_name = columns[0]
                
                cleaned_text = _clean_text(text)
                
                if not os.path.exists(out_dir):
                    os.mkdir(out_dir)
                
                audio_file_path = os.path.join(in_dir, "wavs", f"{file_name}.wav")
                
                if os.path.exists(audio_file_path):
                    # print("path exists")
                    with open(os.path.join(out_dir, f"{file_name}.txt"), "w") as new_text_file:
                        new_text_file.write(cleaned_text) 
                           
                    wav, _ = librosa.load(audio_file_path)
                    wav = (wav / max(abs(wav))) * max_wav_val
                    
                    wavfile.write(
                        os.path.join(out_dir, f"{file_name}.wav"),
                        sampling_rate,
                        wav.astype(np.int16)
                        )
        
        
    # Generate the data for training the different components
    # Here we calculate the pitch and energy of each wav file            
    def generate_training_data(self):
        
        
        os.makedirs((os.path.join(self.out_dir, "duration")), exist_ok=True)
        os.makedirs((os.path.join(self.out_dir, "pitch")), exist_ok=True)
        os.makedirs((os.path.join(self.out_dir, "energy")), exist_ok=True)
        os.makedirs((os.path.join(self.out_dir, "mel")), exist_ok=True)
        
        
        out = list()
        n_frames = 0
        pitch_scaler = StandardScaler()
        energy_scaler = StandardScaler()
        
        
        print("Generating Data for training")
        
        wav_files = []
        
        # returns wav_files
        for file_name in os.listdir(self.in_dir):
            if file_name.endswith(".wav"):
                wav_files.append(file_name)
        
        assert len(wav_files) != 0
            
        for file_name in tqdm(wav_files, ncols=100):
            file_name = file_name.split(".")[0]
            
            text_grid_path = os.path.join(self.out_dir, "TextGrid", f"{file_name}.TextGrid")
            wav_path = os.path.join(self.in_dir,"{}.wav".format(file_name))
            text_path = os.path.join(self.in_dir,"{}.txt".format(file_name))
            
            if os.path.exists(text_grid_path):
                text_grid = self._read_text_grid(text_grid_path)
                
                # getting the duration from the grid
                phones, durations, start, end = self.get_duration(text_grid.get_tier_by_name("phones"))
                
                # Saving duration values in npy files
                dur_filename = "{}-duration.npy".format(file_name)
                np.save(os.path.join(self.out_dir, "duration", dur_filename), durations)
                
                text = "{" + " ".join(phones) + "}"
                
                # read and trim waves (removing starting silence and ending silence)
                wav, _ = librosa.load(wav_path)
                wav = wav[
                    int(self.sampling_rate * start): int(self.sampling_rate * end)
                ].astype(np.float32)
                
                # reading the corresponding text
                with open(text_path) as text_file:
                    raw_text = text_file.readline().strip("\n")
                
                # calculating the fundamental frequency (this will be our pitch)
                pitch, t = pw.dio(
                    wav.astype(np.float64),
                    self.sampling_rate,
                    frame_period = self.hop_length/self.sampling_rate * 1000
                    
                )
                # smooths out the pitch contour
                pitch = pw.stonemask(wav.astype(np.float64), pitch, t, self.sampling_rate)
                # makes sure that the length of the pitch contour matches the total duration
                pitch = pitch[:sum(durations)]
                
                # calculating the mel_scale spectrogram and energy (energy is the l2-norm of each spectogram frame)
                mel, energy = audio.tools.get_mel_from_wav(wav, self.stft)
                # makes sure that the length of the energy countour and the generated spectrogram matches the total duration
                mel = mel[:, :sum(durations)]
                energy = energy[:sum(durations)]
                
                
                # filling in the empty pitch using liner interpolation
                nonzero_ids = np.where(pitch != 0)[0]
                inter_pol = interp1d(
                    nonzero_ids,
                    pitch[nonzero_ids],
                    fill_value=(pitch[nonzero_ids[0]], pitch[nonzero_ids[-1]]),
                    bounds_error=False
                    )
                pitch = inter_pol(np.arange(0, len(pitch)))
                
                # performing phone averaging 
                # ensure that only one pitch and energy is associated with each phones
                
                # averaging for pitch and energy
                pos = 0
                for i, d in enumerate(durations):
                    if d > 0:
                        pitch[i] = np.mean(pitch[pos: pos + d])
                        energy[i] = np.mean(energy[pos: pos + d])
                    else:
                        pitch[i] = 0
                        energy[i] = 0
                    pos += d
                    
                
                    
                pitch = pitch[:len(durations)]
                energy = energy[:len(durations)]
                
                # Saving the numpy arrays
                # Saving pitch array
                pitch_filename = "{}-pitch.npy".format(file_name)
                np.save(os.path.join(self.out_dir, "pitch", pitch_filename), pitch)
                # Saving energy array
                energy_filename = "{}-energy.npy".format(file_name)
                np.save(os.path.join(self.out_dir, "energy", energy_filename), energy)
                # Saving mel spectrogram array
                mel_filename = "{}-mel.npy".format(file_name)
                np.save(
                    os.path.join(self.out_dir, "mel", mel_filename),
                    mel.T,
                )
                
                
                info = "|".join([file_name, text, raw_text])
                pitch = self._remove_outlier(pitch)
                energy = self._remove_outlier(energy)
                n = mel.shape[1]
            
            
            out.append(info)
            
            if len(pitch) > 0:
                    pitch_scaler.partial_fit(pitch.reshape((-1, 1)))
            if len(energy) > 0:
                energy_scaler.partial_fit(energy.reshape((-1, 1)))

            n_frames += n
        
        # normalizing pitch and energy values
        pitch_mean = pitch_scaler.mean_[0]
        pitch_std = pitch_scaler.scale_[0]
        
        energy_mean = energy_scaler.mean_[0]
        energy_std = energy_scaler.scale_[0]
        
        # the function normalizes the values from the given directory and again save the values
        pitch_min, pitch_max = self._normalize(
            os.path.join(self.out_dir, "pitch"), pitch_mean, pitch_std
        )
        energy_min, energy_max = self._normalize(
            os.path.join(self.out_dir, "energy"), energy_mean, energy_std
        )
        
        # saving the min, max, mean and std values of pitch and energy for later use.
        with open(os.path.join(self.out_dir, "stats.json"), "w") as f:
            stats = {
                "pitch": [
                    float(pitch_min),
                    float(pitch_max),
                    float(pitch_mean),
                    float(pitch_std),
                ],
                "energy": [
                    float(energy_min),
                    float(energy_max),
                    float(energy_mean),
                    float(energy_std),
                ],
            }
            f.write(json.dumps(stats))
            
        print(
            "Total time: {} hours".format(
                n_frames * self.hop_length / self.sampling_rate / 3600
            )
        )
        
        # Creating train and validation set
        random.shuffle(out)
        out = [r for r in out if r is not None]
        
        # Saving sets for train and test
        with open(os.path.join(self.out_dir, "train.txt"), "w", encoding="utf-8") as f:
            for m in out[self.val_size :]:
                f.write(m + "\n")
        with open(os.path.join(self.out_dir, "val.txt"), "w", encoding="utf-8") as f:
            for m in out[: self.val_size]:
                f.write(m + "\n")
                
        return out
                
                
                
    # get the duration of each phones
    def get_duration(self, text_grid):
        # represent the silent phones
        silent_phones = ["sil", "sp", "spn"]
        
        phones = []
        durations = []
        start_time = 0
        end_time = 0
        end_idx = 0
        
        for t in text_grid._objects:
            s, e, p = t.start_time, t.end_time, t.text
            
            # check if the phones starts with a silence
            if phones == []:
                if p in silent_phones:
                    continue
                else:
                    start_time = s
            
            # the phone is not silent assume the end of current phone to be the end of the sequence
            # for ordinary phones
            if p not in silent_phones:
                phones.append(p)
                end_time = e
                end_idx = len(phones)
            # for silent phones
            else:
                phones.append(p)
                
            durations.append(
                int(np.round(e * self.sampling_rate / self.hop_length)
                    - np.round(s * self.sampling_rate / self.hop_length))
            )
            
        # remove if silence is present in the end
        phones = phones[:end_idx]
        durations = durations[:end_idx]
            
        return phones, durations, start_time, end_time
                
        
    def _remove_outlier(self, values):
        values = np.array(values)
        p25 = np.percentile(values, 25)
        p75 = np.percentile(values, 75)
        lower = p25 - 1.5 * (p75 - p25)
        upper = p75 + 1.5 * (p75 - p25)
        normal_indices = np.logical_and(values > lower, values < upper)

        return values[normal_indices]      
    
    def _normalize(self, in_dir, mean, std):
        max_value = np.finfo(np.float64).min
        min_value = np.finfo(np.float64).max
        for filename in os.listdir(in_dir):
            filename = os.path.join(in_dir, filename)
            values = (np.load(filename) - mean) / std
            np.save(filename, values)

            max_value = max(max_value, max(values))
            min_value = min(min_value, min(values))

        return min_value, max_value
  
                
    def _read_text_grid(self, text_grid_name):
        return tgt.io.read_textgrid(text_grid_name)

# %%
p = Preprocessor("./preprocess.yaml")
p.config
# Out:
# {'dataset': 'LJSpeech',
#  'path': {'corpus_path': './LJSpeech',
#   'lexicon_path': './lexicon/lexicon.txt',
#   'raw_path': './normalized_audio',
#   'preprocessed_path': './processed_data'},
#  'preprocessing': {'val_size': 512,
#   'text': {'text_cleaners': ['english_cleaners'], 'language': 'en'},
#   'audio': {'sampling_rate': 22050, 'max_wav_value': 32768.0},
#   'stft': {'filter_length': 1024, 'hop_length': 256, 'win_length': 1024},
#   'mel': {'n_mel_channels': 80, 'mel_fmin': 0, 'mel_fmax': 8000},
#   'pitch': {'feature': 'phoneme_level', 'normalization': True},
#   'energy': {'feature': 'phoneme_level', 'normalization': True}}}

# %%
p.preprocess_normalize()
# Out:
# 13100it [08:31, 25.59it/s]

# %%
p.generate_training_data()
# Out:
# Generating Data for training
#   0%|                                                                       | 0/100 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████| 100/100 [00:14<00:00,  6.80it/s]
# Total time: 0.1798095238095238 hours
# ["LJ001-0066|{IH1 N F AE1 K T sp G AH1 N TH ER0 spn EH1 S F ER1 S T T AY1 P sp AE1 F T ER0 W ER0 D Z Y UW1 Z D B AY1 spn sp IH1 Z R IH0 M AA1 R K AH0 B L IY0 L AY1 K DH IY0 T AY1 P sp AH1 V DH AH0 B IH0 F AO1 R M EH1 N SH AH0 N D S UW0 B IY1 AH0 K OW0 B UH1 K S}|in fact gunther zeiner's first type (afterwards used by schussler) is remarkably like the type of the before-mentioned subiaco books.",
#  'LJ001-0027|{AH0 S P EH1 SH AH0 L IY0 EH1 Z R IH0 G AA1 R D Z DH AH1 L OW1 ER0 K EY1 S L EH1 T ER0 Z sp AE1 N D sp T AY1 P V EH1 R IY0 S IH1 M AH0 L ER0 W AH1 Z Y UW1 Z D D Y UH1 R IH0 NG DH AH0 N EH1 K S T F IH1 F T IY1 N AO1 R T W EH1 N T IY0 Y IH1 R Z sp N AA1 T OW1 N L IY0 B AY1 SH OW1 F ER0}|especially as regards the lower-case letters; and type very similar was used during the next fifteen or twenty years not only by schoeffer,',
#  'LJ001-0144|{DH AH1 W ER1 D Z M EY1 B IY1 S EH1 T M AH1 CH K L OW1 S ER0 T AH0 G EH1 DH ER0 sp W IH0 DH AW1 T L AO1 S AH0 V K L EH1 R N AH0 S}|the words may be set much closer together, without loss of clearness.',
#  'LJ001-0004|{P R AH0 D UW1 S T DH AH0 B L AA1 K B UH1 K S sp W IH1 CH W ER1 DH IY0 IH0 M IY1 D IY0 AH0 T P R EH1 D AH0 S EH2 S ER0 Z AH0 V DH AH0 T R UW1 P R IH1 N T AH0 D B UH1 K}|produced the block books, which were the immediate predecessors of the true printed book,',
#  'LJ001-0064|{M EH1 N IY0 AH0 V HH UW1 Z T AY1 P S IH0 N D IY1 D L AY1 K DH AE1 T AH0 V sp DH IY0 S UW0 B IY1 AH0 K OW0 W ER1 K S sp AA1 R AH1 V AH0 T R AE0 N Z IH1 SH AH0 N AH0 L K EH1 R IH0 K T ER0}|many of whose types, indeed, like that of the subiaco works, are of a transitional character.',
#  'LJ001-0090|{W IH1 DH DH IH1 S CH EY1 N JH sp DH IY0 AA1 R T AH0 V P R IH1 N T IH0 NG T AH1 CH T sp B AA1 T AH0 M}|with this change the art of printing touched bottom,',
#  'LJ001-0058|{AE1 N D AA1 R W ER1 DH IY0 R EH2 P R IH0 Z EH1 N T AH0 T IH0 V Z sp AH1 V DH IY0 IY1 G ER0 IH0 N TH UW1 Z IY0 AE2 Z AH0 M sp F R ER0 DH AH1 R IH0 V AY1 V D L ER1 N IH0 NG AH1 V DH AE1 T EH1 P AH0 K sp B AY1 F AA1 R}|and are worthy representatives of the eager enthusiasm for the revived learning of that epoch. by far,',
#  'LJ001-0055|{S AH1 M AH1 V W IH1 CH sp spn AE1 Z sp spn DH AE1 T AH1 V sp JH AH0 K OW1 B AH0 S spn sp AO1 R sp ZH AA1 K L AH0 sp R UW1 ZH spn sp IH1 Z S K EH1 R S L IY0 D IH0 S T IH1 NG G W IH0 SH AH0 B AH0 L F ER0 M HH IH1 Z}|some of which -- as, e.g., that of jacobus rubeus or jacques le rouge -- is scarcely distinguishable from his.',
#  'LJ001-0014|{AE1 N D IH1 T W AH1 Z AH0 M AE1 T ER0 AH0 V K AO1 R S DH AE1 T sp IH1 N DH AH0 M IH1 D AH0 L EY1 JH IH0 Z sp W EH1 N DH AH1 K R AE1 F T S M EH0 N T UH1 K K EH1 R DH AE1 T B Y UW1 T AH0 F AH0 L F AO1 R M SH UH1 D AO1 L W IY0 Z B IY1 AH0 P AA1 R T AH0 V sp DH EH1 R P ER0 D AH1 K SH AH0 N Z sp HH W AH2 T EH1 V ER0 DH EY1 W ER0}|and it was a matter of course that in the middle ages, when the craftsmen took care that beautiful form should always be a part of their productions whatever they were,',
#  'LJ001-0019|{AE1 N D W IH1 CH D IH0 V EH1 L AH0 P T M AO1 R K AH0 M P L IY1 T L IY0 AH0 N D S AE2 T IH0 S F AE1 K T R AH0 L IY0 AA1 N DH AH1 S AY1 D AH0 V DH AH1 L OW1 ER0 K EY1 S sp DH AE1 N DH IY0 K AE1 P AH0 T AH0 L L EH1 T ER0 Z}|and which developed more completely and satisfactorily on the side of the "lower-case" than the capital letters;',
#  'LJ001-0017|{DH AE1 T DH AH1 F AO1 R M Z AH0 V P R IH1 N T AH0 D L EH1 T ER0 Z SH UH1 D F AA1 L OW0 M AO1 R ER0 L EH1 S K L OW1 S L IY0 DH OW1 Z AH0 V DH AH1 R IH1 T AH0 N K EH1 R IH0 K T ER0 sp AH0 N D DH EY1 F AA1 L OW0 D DH AH0 M V EH1 R IY0 K L OW1 S L IY0}|that the forms of printed letters should follow more or less closely those of the written character, and they followed them very closely.',
#  'LJ001-0065|{DH IH1 S W AH0 Z N OW1 T AH0 B L IY0 DH IY0 K EY1 S W IH1 DH DH IY0 ER1 L IY0 W ER1 K S P R IH1 N T IH0 D AE1 T sp AH1 L M sp AE1 N D IH1 N AH0 S AH1 M W AH1 T L EH1 S ER0 D IH0 G R IY1 AE1 T AO1 G Z B ER0 G}|this was notably the case with the early works printed at ulm, and in a somewhat lesser degree at augsburg.',
#  'LJ001-0015|{DH AH1 F AO1 R M Z AH0 V P R IH1 N T AH0 D L EH1 T ER0 Z SH UH1 D B IY0 B Y UW1 T AH0 F AH0 L sp AH0 N D DH AE1 T DH EH1 R ER0 EY1 N JH M AH0 N T AO1 N DH AH0 P EY1 JH sp SH UH1 D B IY1 R IY1 Z N AH0 B AH0 L sp AH0 N D AH0 HH EH1 L P T IH0 DH AH0 SH EY1 P L IY0 N AH0 S AH0 V DH AH1 L EH1 T ER0 Z DH AH0 M S EH1 L V Z}|the forms of printed letters should be beautiful, and that their arrangement on the page should be reasonable and a help to the shapeliness of the letters themselves.',
#  'LJ001-0003|{F AO1 R AO2 L DH OW1 sp DH AH1 CH AY0 N IY1 Z T UH1 K IH0 M P R EH1 SH AH0 N Z sp F R AH1 M W UH1 D B L AA1 K S sp IH0 N G R EY1 V D IH1 N R IH0 L IY1 F sp F ER0 S EH1 N CH ER0 IY0 Z B IH0 F AO1 R DH AH0 W UH1 D K AH2 T ER0 Z AH1 V DH AH0 N EH1 DH ER0 L AH0 N D Z sp B AY1 AH0 S IH1 M AH0 L ER0 P R AA1 S EH2 S}|for although the chinese took impressions from wood blocks engraved in relief for centuries before the woodcutters of the netherlands, by a similar process',
#  "LJ001-0057|{P AA1 R M AH0 sp AH0 N D HH W AH1 N AO1 R T UW1 AH1 DH ER0 S IH1 T IY0 Z sp HH UW1 P R AH0 D UW1 S T DH AH0 S P L EH1 N D AH0 D IH0 D IH1 SH AH0 N Z AH0 V DH AH0 K L AE1 S IH0 K S sp W IH1 CH AA1 R W AH1 N AH0 V DH AH0 G R EY1 T G L AO1 R IY0 Z AH0 V DH AH1 P R IH1 N T ER0 Z AA1 R T}|parma, and one or two other cities, who produced the splendid editions of the classics, which are one of the great glories of the printer's art,",
#  'LJ001-0012|{AH0 S P EH1 SH AH0 L IY0 AE1 Z N OW1 M AO1 R T AY1 M IH0 Z AA1 K Y AH0 P AY2 D sp AO1 R K AA1 S T IH0 N K ER1 D sp IH1 N K AE1 S T IH0 NG sp S EH1 T IH0 NG sp AO1 R P R IH1 N T IH0 NG B Y UW1 T AH0 F AH0 L L EH1 T ER0 Z}|especially as no more time is occupied, or cost incurred, in casting, setting, or printing beautiful letters',
#  "LJ001-0079|{K AE1 S L AH0 N Z T AY1 P IH1 Z K L IH1 R AE1 N D sp N IY1 T sp AH0 N D sp F EH1 R L IY0 W EH1 L D IH0 Z AY1 N D}|caslon's type is clear and neat, and fairly well designed;",
#  'LJ001-0077|{IH1 N IH1 NG G L AH0 N D sp AH0 B AW1 T DH IH1 S T AY1 M AE1 N AH0 T EH1 M P T W AH0 Z M EY1 D sp N OW1 T AH0 B L IY0 B AY1 K AE1 S L AH0 N HH UW1 S T AA1 R T AH0 D B IH1 Z N IH0 S IH0 N L AH1 N D AH0 N AE1 Z AH0 T AY1 P spn sp IH1 N S EH1 V AH0 N T IY1 N T W EH1 N T IY0}|in england about this time, an attempt was made (notably by caslon, who started business in london as a type-founder in seventeen twenty)',
#  'LJ001-0026|{AA1 N DH AH1 HH OW1 L sp DH AH0 T AY1 P AH0 V DH IH1 S B UH1 K M EY1 B IY1 K AH0 N S IH1 D ER0 D sp DH AH1 spn sp P L AH1 S AH1 L T R AH0 AH1 V G AA1 TH IH0 K T AY1 P}|on the whole the type of this book may be considered the ne-plus-ultra of gothic type,',
#  'LJ001-0068|{DH IY0 K EH2 R AH0 K T ER0 IH1 S T IH0 K sp D AH1 CH T AY1 P EH1 Z R EH2 P R IH0 Z EH1 N T IH0 D B AY1 DH IY0 EH1 K S AH0 L AH0 N T P R IH1 N T ER0 sp JH ER0 AA1 R D spn sp IH1 Z V EH1 R IY0 P R AH0 N AW1 N S T AE1 N D sp AH0 N K AA1 M P R AH0 M AY0 Z IH0 NG G AA1 TH IH0 K}|the characteristic dutch type, as represented by the excellent printer gerard leew, is very pronounced and uncompromising gothic.',
#  'LJ001-0117|{W IH1 CH T AY1 T AH0 L K AE1 N OW1 N L IY0 B IY0 K L EY1 M D B AY1 AA0 R T IH1 S T IH0 K P R AE1 K T AH0 S sp W EH1 DH ER0 DH IY0 AA1 R T sp IH1 N IH1 T sp B IY1 K AA1 N SH AH0 S sp AO1 R AH2 N K AA1 N SH AH0 S}|which title can only be claimed by artistic practice, whether the art in it be conscious or unconscious.',
#  'LJ001-0046|{DH EH1 R T AY1 P sp IH1 Z AA1 N DH AH1 L AY1 N Z AH0 V sp DH AH0 JH ER1 M AH0 N AE1 N D F R EH1 N CH sp R AE1 DH ER0 DH AE1 N AH1 V DH AH1 R OW1 M AH0 N P R IH1 N T ER0 Z}|their type is on the lines of the german and french rather than of the roman printers.',
#  'LJ001-0040|{AE1 N D IH1 Z V EH1 R IY0 S IH1 M P AH0 L sp AE1 N D L EH1 JH AH0 B AH0 L sp AE1 N D sp AH0 N AH0 F EH1 K T IH0 D L IY0 D IH0 Z AY1 N D F ER0 Y UW1 S sp B AH1 T IH1 T IH1 Z B AY1 N OW1 M IY1 N Z sp W IH0 DH AW1 T B Y UW1 T IY0}|and is very simple and legible, and unaffectedly designed for use; but it is by no means without beauty.',
#  'LJ001-0031|{IH1 N F AO1 R T IY1 N S IH1 K S T IY0 F AY1 V sp spn sp AE1 N D spn B IY0 G AE1 N P R IH1 N T IH0 NG IH1 N DH AH0 M AA1 N AH0 S T EH2 R IY0 sp AH1 V S UW0 B IY1 AH0 K OW0 sp N IH1 R R OW1 M}|in fourteen sixty-five sweynheim and pannartz began printing in the monastery of subiaco near rome,',
#  'LJ001-0005|{DH IY0 IH0 N V EH1 N SH AH0 N AH0 V M UW1 V AH0 B AH0 L M EH1 T AH0 L L EH1 T ER0 Z IH0 N DH AH0 M IH1 D AH0 L AH1 V DH AH0 F IH0 F T IY1 N TH S EH1 N CH ER0 IY0 sp M EY1 JH AH1 S T L IY0 B IY1 K AH0 N S IH1 D ER0 D sp AE1 Z DH IY0 IH0 N V EH1 N SH AH0 N AH0 V DH IY0 AA1 R T AH0 V P R IH1 N T IH0 NG}|the invention of movable metal letters in the middle of the fifteenth century may justly be considered as the invention of the art of printing.',
#  'LJ001-0042|{AE1 N D DH OW1 M AO1 R R OW1 M AH0 N DH AE1 N DH AE1 T sp Y EH1 T S K EH1 R S L IY0 M AO1 R L AY1 K DH IY0 K AH0 M P L IY1 T R OW1 M AH0 N T AY1 P AH1 V DH IY0 ER1 L IY0 AH0 S T P R IH1 N T ER0 Z AH0 V R OW1 M}|and though more roman than that, yet scarcely more like the complete roman type of the earliest printers of rome.',
#  'LJ001-0062|{IY1 V IH0 N IH1 N IH1 T AH0 L IY0 sp M OW1 S T AH0 V DH AH0 TH IY2 AH0 L AA1 JH IH0 K AH0 L AE1 N D L AA1 B UH1 K S W ER0 P R IH1 N T IH0 D IH0 N G AA1 TH IH0 K L EH1 T ER0}|even in italy most of the theological and law books were printed in gothic letter,',
#  'LJ001-0082|{IH1 N S P AY1 T HH AW2 EH1 V ER0 AH0 V HH IH1 Z P R EY1 Z W ER2 DH IY0 EH1 F ER0 T S sp P R IH1 N T IH0 NG HH AE1 D S T IH1 L W AH1 N L AE1 S D EH2 G R AH0 D EY1 SH AH0 N T UW1 AH2 N D ER0 G OW1}|in spite, however, of his praiseworthy efforts, printing had still one last degradation to undergo.',
#  'LJ001-0006|{AE1 N D sp IH1 T IH1 Z W ER1 TH M EH1 N SH AH0 N IH1 N P AE1 S IH0 NG sp DH AE1 T sp AE1 Z AE1 N IH0 G Z AE1 M P AH0 L AH1 V F AY1 N T AH0 P AA1 G R AH0 F IY0}|and it is worth mention in passing that, as an example of fine typography,',
#  'LJ001-0063|{W IH1 CH W AH0 Z JH EH1 N ER0 AH0 L IY0 M AO1 R F AO1 R M AH0 L IY0 G AA1 TH IH0 K sp DH AE1 N DH AH1 P R IH1 N T IH0 NG AH0 V DH AH0 JH ER1 M AH0 N W ER1 K M IH0 N}|which was generally more formally gothic than the printing of the german workmen,',
#  'LJ001-0037|{AE1 N D DH AH0 N EH1 K S T Y IH1 R sp G AH1 N TH ER0 spn sp AE1 T AO1 G Z B ER0 G F AA1 L OW0 D S UW1 T}|and the next year gunther zeiner at augsburg followed suit;',
#  'LJ001-0083|{DH AH0 S EH1 V AH0 N T IY1 N TH S EH1 N CH ER0 IY0 F AW1 N T S sp W ER1 sp B AE1 D R AE1 DH ER0 N EH1 G AH0 T IH0 V L IY0 DH AE1 N P AA1 Z AH0 T IH0 V L IY0}|the seventeenth century founts were bad rather negatively than positively.',
#  'LJ001-0076|{AE1 N D TH IH1 NG Z G AA1 T W ER1 S AH0 N D W ER1 S sp TH R UW1 DH AH1 HH OW1 L AH1 V DH IY0 S EH1 V AH0 N T IY1 N TH S EH1 N CH ER0 IY0 sp S OW1 DH AE1 T sp IH1 N DH IY0 EY1 T IY1 N TH sp P R IH1 N T IH0 NG sp W AH1 Z V EH1 R IY0 M IH1 Z ER0 AH0 B L IY0 P ER0 F AO1 R M D}|and things got worse and worse through the whole of the seventeenth century, so that in the eighteenth printing was very miserably performed.',
#  'LJ001-0049|{AE1 F T ER0 HH IH1 Z D EH1 TH IH1 N DH AH0 F AO1 R T IY1 N sp EY1 T IY0 Z sp AO1 R AE1 T L IY1 S T B AY1 F AO1 R T IY1 N sp N AY1 N T IY0 sp P R IH1 N T IH0 NG IH1 N V EH1 N AH0 S HH AE1 D D IH0 K L AY1 N D V EH1 R IY0 M AH1 CH}|after his death in the "fourteen eighties," or at least by fourteen ninety, printing in venice had declined very much;',
#  'LJ001-0081|{T AY1 P K AE1 S T F ER0 M HH IH1 Z M EY1 T R IH0 S IH0 Z sp IH1 Z S T IH1 L IH1 N EH1 V R IY0 D EY1 Y UW1 S}|type cast from his matrices is still in everyday use.',
#  'LJ001-0021|{DH IY0 ER1 L IY0 AH0 S T B UH1 K sp P R IH1 N T IH0 D W IH1 TH M UW1 V AH0 B AH0 L T AY1 P sp DH IY0 AH0 F AO1 R S EH2 D G UW1 T AH0 N B ER0 G B AY1 B AH0 L sp IH1 Z P R IH1 N T AH0 D IH1 N L EH1 T ER0 Z sp W IH1 CH AA1 R AH0 N IH0 G Z AE1 K T IH2 M AH0 T EY1 SH AH0 N}|the earliest book printed with movable type, the aforesaid gutenberg bible, is printed in letters which are an exact imitation',
#  'LJ001-0047|{AH1 V JH EH1 N S AH0 N IH1 T M AH1 S T B IY1 S EH1 D sp DH AE1 T HH IY1 K AE1 R IY0 D DH IY0 D IH0 V EH1 L AH0 P M AH0 N T AH0 V R OW1 M AH0 N T AY1 P EH1 Z F AA1 R EH1 Z IH1 T K AH0 N G OW1}|of jenson it must be said that he carried the development of roman type as far as it can go:',
#  "LJ001-0071|{M OW1 S T AH0 V K AE1 K S T AH0 N Z OW1 N T AY1 P S sp AA1 R AH1 V AH0 N ER1 L IY0 ER0 K EH1 R IH0 K T ER0 sp DH OW1 DH EY1 sp AO1 L S OW0 M AH1 CH R IH0 Z EH1 M B AH0 L F L EH1 M IH0 SH AO1 R K AH0 L OW1 N L EH1 T ER0}|most of caxton's own types are of an earlier character, though they also much resemble flemish or cologne letter.",
#  'LJ001-0033|{B AH1 T W IH1 CH M AH1 S T S ER1 T AH0 N L IY0 HH AE1 V K AH1 M F R AH1 M DH AH0 S T AH1 D IY0 AH1 V sp DH AH0 T W EH1 L F TH sp AO1 R IY1 V IH0 N DH IY0 sp IH0 L EH1 V AH0 N TH S EH1 N CH ER0 IY0 sp M EH1 S}|but which must certainly have come from the study of the twelfth or even the eleventh century mss.',
#  'LJ001-0045|{F AO1 R T IY1 N S IH1 K S T IY0 N AY1 N sp F AO1 R T IY1 N S EH1 V AH0 N T IY0}|fourteen sixty-nine, fourteen seventy;',
#  'LJ001-0067|{IH1 N DH AH0 L OW1 K AH1 N T R IY0 Z AE1 N D K AH0 L OW1 N sp W IH1 CH W ER0 V EH1 R IY0 F ER1 T AH0 L sp AH1 V P R IH1 N T IH0 D B UH1 K S sp G AA1 TH IH0 K W AA1 Z DH AH0 F EY1 V ER0 IH0 T}|in the low countries and cologne, which were very fertile of printed books, gothic was the favorite.',
#  'LJ001-0135|{IH1 T IH1 Z IH0 M P AA1 S AH0 B AH0 L DH AE1 T DH EY1 SH UH1 D B IY1 K W AY1 T IY1 K W AH0 L sp IH0 K S EH1 P T IH0 N L AY1 N Z AH0 V P OW1 AH0 T R IY0}|it is impossible that they should be quite equal except in lines of poetry',
#  'LJ001-0010|{N AW1 sp AE1 Z AO1 L B UH1 K S sp N AA1 T P R AY0 M EH1 R AH0 L IY0 IH0 N T EH1 N D IH0 D EH1 Z sp P IH1 K CH ER0 B UH1 K S sp K AH0 N S IH1 S T P R IH1 N S IH0 P L IY0 AH0 V T AY1 P S K AH0 M P OW1 Z D sp T AH0 F AO1 R M L EH1 T ER0 P R EH2 S}|now, as all books not primarily intended as picture-books consist principally of types composed to form letterpress,',
#  'LJ001-0007|{DH IY0 ER1 L IY0 AH0 S T B UH1 K P R IH1 N T IH0 D W IH1 TH M UW1 V AH0 B AH0 L T AY1 P S sp DH IY0 G UW1 T AH0 N B ER0 G sp AO1 R sp F AO1 R T IY0 T UW1 L AY1 N B AY1 B AH0 L sp AH1 V AH0 B AW1 T F AO1 R T IY1 N F IH1 F T IY0 F AY1 V}|the earliest book printed with movable types, the gutenberg, or "forty-two line bible" of about fourteen fifty-five,',
#  'LJ001-0029|{B AH1 T sp DH OW1 AO1 N DH AH1 HH OW1 L sp IH0 K S EH1 P T IH1 N IH1 T AH0 L IY0 sp G AA1 TH IH0 K L EH1 T ER0 W AH1 Z M OW1 S T AO1 F AH0 N Y UW1 Z D}|but though on the whole, except in italy, gothic letter was most often used',
#  'LJ001-0094|{W ER0 IH0 N D UW1 S T T AH0 K AH1 T P AH1 N CH IH0 Z F R ER0 AH0 S IH1 R IY0 Z AH0 V OW1 L D S T AY1 L L EH1 T ER0 Z}|were induced to cut punches for a series of "old style" letters.',
#  'LJ001-0073|{W EH1 N T AA1 N AH0 P EY1 S sp AE1 N D B AY1 DH IY0 EH1 N D AH0 V DH IY0 S IH1 K S T IY1 N TH S EH1 N CH ER0 IY0 sp DH EH1 R W AH1 Z N OW1 R IY1 L IY0 B Y UW1 T AH0 F AH0 L P R IH1 N T IH0 NG D AH1 N}|went on apace; and by the end of the sixteenth century there was no really beautiful printing done:',
#  'LJ001-0044|{JH AA1 N AH0 V S P AY1 R Z AH0 N D HH IH1 Z B R AH1 DH ER0 spn sp F AA1 L OW0 D B AY1 N IH1 K AH0 L AH0 S JH EH1 N S AH0 N sp B IY0 G AE1 N T UW1 P R IH1 N T IH1 N DH AE1 T S IH1 T IY0}|john of spires and his brother vindelin, followed by nicholas jenson, began to print in that city,',
#  'LJ001-0039|{DH AH1 R OW1 M AH0 N T AY1 P sp AH1 V AO1 L DH IY1 Z P R IH1 N T ER0 Z sp IH1 Z S IH1 M AH0 L ER0 IH0 N K EH1 R IH0 K T ER0}|the roman type of all these printers is similar in character,',
#  'LJ001-0043|{AH0 sp F ER1 DH ER0 D IH0 V EH1 L AH0 P M AH0 N T AH0 V DH AH0 R OW1 M AH0 N L EH1 T ER0 sp T UH1 K P L EY1 S AE1 T V EH1 N IH0 S}|a further development of the roman letter took place at venice.',
#  'LJ001-0072|{AE1 F T ER0 DH IY0 EH1 N D AH0 V sp DH AH0 F IH0 F T IY1 N TH S EH1 N CH ER0 IY0 sp DH IY0 D EH2 G R AH0 D EY1 SH AH0 N AH0 V P R IH1 N T IH0 NG sp AH0 S P EH1 SH AH0 L IY0 IH1 N JH ER1 M AH0 N IY0 AE1 N D sp IH1 T AH0 L IY0}|after the end of the fifteenth century the degradation of printing, especially in germany and italy,',
#  'LJ001-0011|{IH1 T IH1 Z AH1 V DH AH1 F ER1 S T IH0 M P AO1 R T AH0 N S sp DH AE1 T DH AH0 L EH1 T ER0 Y UW1 Z D SH UH1 D B IY1 F AY1 N IH0 N F AO1 R M}|it is of the first importance that the letter used should be fine in form;',
#  'LJ001-0088|{W ER0 DH AH0 L IY1 D ER0 Z IH0 N DH IH1 S L AH1 K L AH0 S CH EY1 N JH sp DH OW1 AW1 R OW1 N B AE1 S K ER0 V IH2 L sp HH UW1 W AH1 Z AE1 T W ER1 K S AH1 M Y ER0 Z B IY2 F AO1 R DH EH1 M sp W EH1 N T M AH1 CH AA1 N DH AH1 S EY1 M L AY1 N Z}|were the leaders in this luckless change, though our own baskerville, who was at work some years before them, went much on the same lines;',
#  'LJ001-0020|{DH AH0 L OW1 ER0 K EY1 S B IY1 IH0 NG IH1 N F AE1 K T IH0 N V EH1 N T IH0 D sp IH1 N DH IY0 ER1 L IY0 M IH1 D AH0 L sp EY1 JH IH0 Z}|the "lower-case" being in fact invented in the early middle ages.',
#  "LJ001-0052|{Y EH1 T DH EH1 R T AY1 P IH1 Z AA0 R T IH1 S T IH0 K L IY0 AA1 N AH0 M AH1 CH L OW1 ER0 L EH1 V AH0 L DH AH0 N JH EH1 N S AH0 N sp EH1 S sp AE1 N D IH1 N F AE1 K T}|yet their type is artistically on a much lower level than jenson's, and in fact",
#  'LJ001-0016|{DH AH1 M IH1 D AH0 L EY1 JH IH0 Z B R AO1 T K AH0 L IH1 G R AH0 F IY0 sp T UW1 P ER0 F EH1 K SH AH0 N sp AE1 N D sp IH1 T W AH1 Z N AE1 CH ER0 AH0 L DH EH1 R F AO2 R}|the middle ages brought calligraphy to perfection, and it was natural therefore',
#  'LJ001-0051|{AE1 N D sp P EY1 IH0 NG G R EY1 T AH0 T EH1 N SH AH0 N T UW1 DH AH0 P R EH1 S W ER1 K sp AO1 R AE1 K SH AH0 L P R AA1 S EH2 S AH0 V P R IH1 N T IH0 NG}|and paying great attention to the "press work" or actual process of printing,',
#  'LJ001-0089|{B AH1 T sp HH IH1 Z L EH1 T ER0 Z sp DH OW1 AH0 N IH1 N T R AH0 S T IH0 NG AE1 N D P UW1 R sp AA1 R N AA1 T N IH1 R L IY0 S OW1 G R OW1 S AE1 N D V AH1 L G ER0 sp AE1 Z DH OW1 Z AH0 V AY1 DH ER0 DH IY0 IH0 T AE1 L Y AH0 N sp AO1 R DH AH0 F R EH1 N CH M AE0 N}|but his letters, though uninteresting and poor, are not nearly so gross and vulgar as those of either the italian or the frenchman.',
#  'LJ001-0056|{IH1 T W AH1 Z DH IY1 Z G R EY1 T V AH0 N IY1 SH AH0 N P R IH1 N T ER0 Z T AH0 G EH1 DH ER0 W IH1 DH DH EH1 R B R EH1 DH R AH0 N AH0 V R OW1 M sp M IH0 L AA1 N}|it was these great venetian printers, together with their brethren of rome, milan,',
#  'LJ001-0025|{IH1 M AH0 T EY2 T S AH0 M AH1 CH F R IY1 ER0 HH AE1 N D sp S IH1 M P L ER0 sp R AW1 N D ER0 AE1 N D L EH1 S S P AY1 K IY0 sp AE1 N D DH EH1 R F AO2 R F AA1 R P L EH1 Z AH0 N T ER0 sp AE1 N D IY1 Z IY0 ER0 T UW1 R IY1 D}|imitates a much freer hand, simpler, rounder, and less spiky, and therefore far pleasanter and easier to read.',
#  'LJ001-0008|{HH AE1 Z N EH1 V ER0 B IH1 N S ER0 P AE1 S T}|has never been surpassed.',
#  'LJ001-0041|{IH1 T M AH1 S T B IY0 S EH1 D sp DH AE1 T IH1 T IH1 Z IH1 N N OW1 W EY1 L AY1 K DH IY0 T R AE0 N Z IH1 SH AH0 N T AY1 P AH0 V S UW0 B IY1 AH0 K OW0}|it must be said that it is in no way like the transition type of subiaco,',
#  'LJ001-0061|{DH AH1 R OW1 M AH0 N L EH1 T ER0 W AH0 Z Y UW1 Z D S AY1 D B AY1 S AY1 D W IH1 TH DH AH0 G AA1 TH IH0 K}|the roman letter was used side by side with the gothic.',
#  'LJ001-0002|{IH1 N B IY1 IH0 NG K AH0 M P EH1 R AH0 T IH0 V L IY0 M AA1 D ER0 N}|in being comparatively modern.',
#  'LJ001-0091|{S OW1 F AA1 R EH1 Z F AY1 N sp P R IH1 N T IH0 NG IH1 Z K AH0 N S ER1 N D sp DH OW1 sp P EY1 P ER0 D IH1 D N AA1 T G EH1 T T UW1 IH1 T S sp W ER1 S T T IH1 L AH0 B AW1 T EY0 T IY1 N F AO1 R T IY0}|so far as fine printing is concerned, though paper did not get to its worst till about eighteen forty.',
#  'LJ001-0078|{T UW1 IH0 M P R UW1 V DH AH0 L EH1 T ER0 IH1 N F AO1 R M}|to improve the letter in form.',
#  "LJ001-0092|{DH AH0 CH IH1 Z W IH0 K P R EH1 S IH1 N EY1 T IY1 N F AO1 R T IY0 F AO1 R R IH0 V AY1 V D K AE1 S L AH0 N Z F AW1 N T S sp P R IH1 N T IH0 NG F ER0 M EH1 S ER0 Z L AO1 NG M AH0 N sp DH AH0 D AY1 R IY0 AH0 V L EY1 D IY0 W IH1 L AH0 B IY0}|the chiswick press in eighteen forty-four revived caslon's founts, printing for messrs. longman the diary of lady willoughby.",
#  'LJ001-0075|{DH AH1 W ER1 S T sp W IH1 CH P ER0 HH AE1 P S W AH1 Z DH IY0 IH1 NG G L IH0 SH sp W AH1 Z AH0 T EH1 R AH0 B AH0 L F AA1 L IH0 NG AO1 F sp F R AH1 M DH AH0 W ER1 K AH0 V DH IY0 ER1 L IY0 ER0 P R EH1 S IH0 Z}|the worst, which perhaps was the english, was a terrible falling-off from the work of the earlier presses;',
#  'LJ001-0032|{AE1 N D Y UW1 Z D AH0 N IH0 K S IY1 D IH0 NG L IY0 B Y UW1 T AH0 F AH0 L T AY1 P sp W IH1 CH IH1 Z IH0 N D IY1 D T AH0 L UH1 K sp AE1 T AH0 sp T R AE0 N Z IH1 SH AH0 N B IY0 T W IY1 N sp G AA1 TH IH0 K AE1 N D R OW1 M AH0 N}|and used an exceedingly beautiful type, which is indeed to look at a transition between gothic and roman,',
#  'LJ001-0070|{AE1 N D W AH1 Z Y UW1 Z D DH EH1 R W IH1 DH V EH1 R IY0 L IH1 T AH0 L V EH2 R IY0 EY1 SH AH0 N sp AO1 L TH R UW1 DH AH1 S IH1 K S T IY1 N TH AE1 N D S EH1 V AH0 N T IY1 N TH S EH1 N CH ER0 IY0 Z sp AH0 N D IH0 N D IY1 D sp IH1 N T UW0 DH IY0 EY1 T IY1 N TH}|and was used there with very little variation all through the sixteenth and seventeenth centuries, and indeed into the eighteenth.',
#  'LJ001-0099|{IH1 T M AH1 S T B IY1 R IH0 M EH1 M B ER0 D HH AW2 EH1 V ER0 sp DH AE1 T M OW1 S T M AA1 D ER0 N sp P R IH1 N T IH0 NG IH1 Z D AH1 N B AY1 M AH0 SH IY1 N R IY0 AA1 N S AO1 F T P EY1 P ER0 sp AE1 N D N AA1 T sp B AY1 DH AH0 HH AE1 N D P R EH1 S}|it must be remembered, however, that most modern printing is done by machinery on soft paper, and not by the hand press,',
#  'LJ001-0013|{DH AE1 N IH1 N DH AH1 S EY1 M AA2 P ER0 EY1 SH AH0 N Z W IH1 DH AH1 G L IY0 W AH1 N Z}|than in the same operations with ugly ones.',
#  'LJ001-0050|{AE1 N D sp DH OW1 DH AH1 F EY1 M AH0 S F AE1 M L IY0 AH1 V AA1 L D IH0 S sp R IH0 S T AO1 R D IH1 T S T EH1 K N IH0 K AH0 L sp EH1 K S AH0 L AH0 N S sp R IH0 JH EH1 K T IH0 NG B AE1 T ER0 D L EH1 T ER0 Z}|and though the famous family of aldus restored its technical excellence, rejecting battered letters,',
#  'LJ001-0024|{B AH1 T DH AH1 F ER1 S T B AY1 B AH0 L sp AE1 K SH AH0 L IY0 D EY1 T IH0 D sp W IH1 CH AO1 L S OW0 W AH1 Z P R IH1 N T AH0 D AE1 T M EY1 N T S B AY1 P IY1 T ER0 SH OW1 F ER0 sp IH1 N DH IY0 Y IH1 R F AO1 R T IY1 N S IH1 K S T IY0 T UW1}|but the first bible actually dated (which also was printed at maintz by peter schoeffer in the year fourteen sixty-two)',
#  'LJ001-0059|{DH AH0 G R EY1 T ER0 P AA1 R T AH0 V DH IY1 Z IH0 T AE1 L Y AH0 N P R IH1 N T ER0 Z sp IH1 T SH UH1 D B IY0 M EH1 N SH AH0 N D sp W ER1 JH ER1 M AH0 N Z AO1 R F R EH1 N CH M EH0 N sp W ER1 K IH0 NG AH1 N D ER0 DH IY0 IH1 N F L UW0 AH0 N S AH0 V IH0 T AE1 L Y AH0 N AH0 P IH1 N Y AH0 N AE1 N D EY1 M Z}|the greater part of these italian printers, it should be mentioned, were germans or frenchmen, working under the influence of italian opinion and aims.',
#  'LJ001-0053|{DH EY1 M AH1 S T B IY1 K AH0 N S IH1 D ER0 D sp T UW1 HH AE1 V sp EH1 N D IH0 D DH IY0 EY1 JH AH1 V F AY1 N P R IH1 N T IH0 NG IH1 N IH1 T AH0 L IY0}|they must be considered to have ended the age of fine printing in italy.',
#  'LJ001-0048|{HH IH1 Z L EH1 T ER0 IH0 Z AE1 D M ER0 AH0 B L IY0 K L IH1 R AE1 N D R EH1 G Y AH0 L ER0 sp B AH1 T sp AE1 T L IY1 S T EH1 Z B Y UW1 T AH0 F AH0 L AE1 Z EH1 N IY0 AH1 DH ER0 R OW1 M AH0 N T AY1 P}|his letter is admirably clear and regular, but at least as beautiful as any other roman type.',
#  'LJ001-0080|{HH IY1 S IY1 M Z T UW1 HH AE1 V T EY1 K AH0 N DH AH1 L EH1 T ER0 AH1 V DH IY0 EH1 L Z AH0 V IH1 R Z AH0 V DH IY0 S EH1 V AH0 N T IY1 N TH S EH1 N CH ER0 IY0 F AO1 R HH IH1 Z M AA1 D AH0 L}|he seems to have taken the letter of the elzevirs of the seventeenth century for his model:',
#  'LJ001-0023|{AE1 N D W AA1 Z IH1 N F AE1 K T DH AH0 K AY1 N D AH0 V L EH1 T ER0 Y UW1 Z D IH0 N DH AH0 M EH1 N IY0 S P L EH1 N D IH0 D M IH1 S AH0 L Z sp S AO1 L T ER0 Z EH2 T S EH1 T ER0 AH0 sp P R AH0 D UW1 S T B AY1 P R IH1 N T IH0 NG IH0 N DH AH0 F IH0 F T IY1 N TH S EH1 N CH ER0 IY0}|and was in fact the kind of letter used in the many splendid missals, psalters, etc., produced by printing in the fifteenth century.',
#  'LJ001-0022|{AH1 V DH AH1 M AO1 R F AO1 R M AH0 L IH0 K L IY2 Z IY0 AE1 S T IH0 K AH0 L R AY1 T IH0 NG sp W IH1 CH AH0 B T EY1 N D AE1 T DH AE1 T T AY1 M sp DH IH1 S HH AE1 Z S IH1 N S B IH1 N K AO1 L D M IH1 S AH0 L T AY1 P}|of the more formal ecclesiastical writing which obtained at that time; this has since been called "missal type,"',
#  'LJ001-0035|{DH EY1 D IH0 S K AA1 R D IH0 D DH IH1 S F AO1 R AH0 M AO1 R K AH0 M P L IY1 T L IY0 R OW1 M AH0 N sp AE1 N D F AA1 R L EH1 S B Y UW1 T AH0 F AH0 L L EH1 T ER0}|they discarded this for a more completely roman and far less beautiful letter.',
#  'LJ001-0060|{IH0 T M AH1 S T B IY1 AH2 N D ER0 S T UH1 D sp DH AE1 T sp TH R UW1 DH AH1 HH OW1 L AH1 V DH AH0 F IH0 F T IY1 N TH sp AE1 N D DH AH1 F ER1 S T K W AO1 R T ER0 sp AH1 V DH IY0 S IH1 K S T IY1 N TH S EH1 N CH ER0 IY0 Z}|it must be understood that through the whole of the fifteenth and the first quarter of the sixteenth centuries',
#  'LJ001-0054|{JH EH1 N S AH0 N HH AW2 EH1 V ER0 sp HH AE1 D M EH1 N IY0 K AH0 N T EH1 M P ER0 EH2 R IY0 Z HH UW1 Y UW1 Z D sp B Y UW1 T AH0 F AH0 L T AY1 P}|jenson, however, had many contemporaries who used beautiful type,',
#  'LJ001-0084|{B AH1 T F R ER0 DH IY0 B Y UW1 T IY0 AH0 V DH IY0 ER1 L IY0 ER0 W ER1 K sp DH EY1 M AY1 T HH AE1 V S IY1 M D T AA1 L ER0 AH0 B AH0 L}|but for the beauty of the earlier work they might have seemed tolerable.',
#  'LJ001-0034|{DH EY1 P R IH1 N T IH0 D V EH1 R IY0 F Y UW1 B UH1 K S IH0 N DH IH1 S T AY1 P sp TH R IY1 OW1 N L IY0 sp B AH1 T sp IH1 N DH EH1 R V EH1 R IY0 F ER1 S T B UH1 K S IH1 N R OW1 M sp B IH0 G IH1 N IH0 NG W IH1 TH DH IY0 Y IH1 R F AO1 R T IY1 N S IH1 K S T IY0 EY1 T}|they printed very few books in this type, three only; but in their very first books in rome, beginning with the year fourteen sixty-eight,',
#  'LJ001-0085|{IH1 T W AH1 Z R IY0 Z ER1 V D F ER0 DH AH0 F AW1 N D ER0 Z AH0 V DH AH0 L EY1 T ER0 EY1 T IY1 N TH S EH1 N CH ER0 IY0 sp T UW1 P R AH0 D UW1 S L EH1 T ER0 Z W IH1 CH ER0 P AA1 Z AH0 T IH0 V L IY0 AH1 G L IY0 sp AE1 N D W IH1 CH IH1 T M EY1 B IY0 AE1 D IH0 D}|it was reserved for the founders of the later eighteenth century to produce letters which are positively ugly, and which, it may be added,',
#  'LJ001-0038|{W AY1 L IH0 N F AO1 R T IY1 N S EH1 V AH0 N T IY0 AE1 T P AE1 R IH0 S sp spn G IH1 R IH0 NG AE1 N D HH IH1 Z AH0 S OW1 S IY0 AH0 T S T ER1 N D AW1 T DH AH0 F ER1 S T B UH1 K S P R IH1 N T IH0 D IH0 N F R AE1 N S sp AO1 L S OW0 sp IH1 N R OW1 M AH0 N K EH1 R IH0 K T ER0}|while in fourteen seventy at paris udalric gering and his associates turned out the first books printed in france, also in roman character.',
#  'LJ001-0093|{DH IH1 S IH0 K S P EH1 R AH0 M AH0 N T W AH1 Z sp S OW1 F AA1 R S AH0 K S EH1 S F AH0 L sp DH AE1 T sp AH0 B AW1 T EY1 T IY1 N F IH1 F T IY0 sp M EH1 S ER0 Z M IH1 L ER0 AE1 N D R IH1 CH ER0 D AH0 V EH1 D AH0 N B ER0 OW0}|this experiment was so far successful that about eighteen fifty messrs. miller and richard of edinburgh',
#  'LJ001-0028|{B AH1 T B AY1 P R IH1 N T ER0 Z IH0 N S T R AE1 S B ER0 G sp B AE1 S AH0 L sp P AE1 R IH0 S sp L UW1 B EH2 K AE1 N D AH1 DH ER0 S IH1 T IY0 Z}|but by printers in strasburg, basle, paris, lubeck, and other cities.',
#  'LJ001-0009|{P R IH1 N T IH0 NG DH EH1 N F AO1 R AW1 ER0 P ER1 P AH0 S sp M EY1 B IY1 K AH0 N S IH1 D ER0 D EH1 Z DH IY0 AA1 R T AH1 V M EY1 K IH0 NG B UH1 K S sp B AY1 M IY1 N Z AH0 V M UW1 V AH0 B AH0 L T AY1 P S}|printing, then, for our purpose, may be considered as the art of making books by means of movable types.',
#  'LJ001-0108|{IH1 T IH1 Z AA1 B V IY0 AH0 S DH AE1 T L EH2 JH AH0 B IH1 L AH0 T IY0 IH1 Z DH AH1 F ER1 S T TH IH1 NG T IH0 B IY0 EY1 M D AE1 T sp IH1 N DH AH1 F AO1 R M Z AH0 V DH AH0 L EH1 T ER0 Z}|it is obvious that legibility is the first thing to be aimed at in the forms of the letters;',
#  'LJ001-0036|{B AH1 T sp AH0 B AW1 T DH AH0 S EY1 M Y IH1 R sp spn AE1 T S T R AE1 S B ER0 G sp B IY0 G AE1 N T UW1 P R IH1 N T IH1 N AH0 T AY1 P HH W IH1 CH IH1 Z D IH0 S T IH1 NG K T L IY0 R OW1 M AH0 N}|but about the same year mentelin at strasburg began to print in a type which is distinctly roman;',
#  "LJ001-0069|{DH IH1 S T AY1 P W AH0 Z IH2 N T R AH0 D UW1 S T IH0 N T UW1 IH1 NG G L AH0 N D sp B AY1 W IH1 NG K IH0 N D IY1 W ER1 D sp K AE1 K S T AH0 N Z sp S AH0 K S EH1 S ER0}|this type was introduced into england by wynkyn de worde, caxton's successor,",
#  'LJ001-0018|{DH AH1 F ER1 S T B UH1 K S W ER0 P R IH1 N T IH0 D IH1 N B L AE1 K L EH1 T ER0 sp spn DH AH1 L EH1 T ER0 W IH1 CH W AH1 Z AH0 G AA1 TH IH0 K D IH0 V EH1 L AH0 P M AH0 N T sp AH1 V DH IY0 EY1 N SH AH0 N T R OW1 M AH0 N K EH1 R IH0 K T ER0}|the first books were printed in black letter, i.e. the letter which was a gothic development of the ancient roman character,',
#  "LJ001-0126|{M OW1 S T AH0 V JH EH1 N S AH0 N EH1 S L EH1 T ER0 Z AA1 R D IH0 Z AY1 N D W IH0 DH IH1 N AH0 S K W EH1 R}|most of jenson's letters are designed within a square,",
#  'LJ001-0086|{AA1 R D AE1 Z AH0 L IH0 NG AE1 N D sp AH0 N P L EH1 Z AH0 N T sp T IH0 DH IY0 AY1 sp OW1 IH0 NG T IH0 DH AH0 K L AH1 M Z IY0 TH IH1 K AH0 N IH0 NG AE1 N D V AH1 L G ER0 TH IH1 N IH0 NG AH1 V DH AH1 L AY1 N Z}|are dazzling and unpleasant to the eye owing to the clumsy thickening and vulgar thinning of the lines:',
#  'LJ001-0087|{F AO1 R DH AH1 S EH1 V AH0 N T IY1 N TH S EH1 N CH ER0 IY0 L EH1 T ER0 Z AA1 R AE1 T L IY1 S T P Y UH1 R AH0 N D S IH1 M P AH0 L IH0 N L AY1 N sp DH IY0 IH0 T AE1 L Y AH0 N sp spn AE1 N D DH AH0 F R EH1 N CH M AE0 N sp D IH0 D OW0}|for the seventeenth-century letters are at least pure and simple in line. the italian, bodoni, and the frenchman, didot,',
#  'LJ001-0074|{DH AH1 B EH1 S T M OW1 S L IY0 F R EH1 N CH sp AO1 R L OW1 K AH1 N T R IY0 sp W AH1 Z N IY1 T AE1 N D sp K L IH1 R sp B AH1 T W IH0 DH AW1 T EH1 N IY0 D IH0 S T IH1 NG K SH AH0 N}|the best, mostly french or low-country, was neat and clear, but without any distinction;',
#  'LJ001-0030|{AH0 V EH1 R IY0 F Y UW1 Y IH1 R Z sp S AO1 DH AH1 B ER1 TH AH0 V R OW1 M AH0 N K EH1 R IH0 K T ER0 sp N AA1 T OW1 N L IY0 IH0 N IH1 T AH0 L IY0 sp B AH1 T IH1 N JH ER1 M AH0 N IY0 AH0 N D F R AE1 N S}|a very few years saw the birth of roman character not only in italy, but in germany and france.',
#  'LJ001-0001|{P R IH1 N T IH0 NG sp IH1 N DH IY0 OW1 N L IY0 S EH1 N S W IH1 DH sp W IH1 CH W IY1 AA1 R AE1 T P R EH1 Z AH0 N T K AH0 N S ER1 N D sp D IH1 F ER0 Z sp F R AH1 M M OW1 S T IH1 F N AA1 T F R AH1 M AO1 L DH IY0 AA1 R T S AH0 N D K R AE1 F T S R EH2 P R IH0 Z EH1 N T IH0 D IH1 N DH IY0 EH2 K S AH0 B IH1 SH AH0 N}|printing, in the only sense with which we are at present concerned, differs from most if not from all the arts and crafts represented in the exhibition']
